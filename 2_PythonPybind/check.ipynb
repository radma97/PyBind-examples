# %%
import summa
s=summa.add(2,3)
print(f"s={s}")
s=summa.add(7,8)
print(f"s={s}")
# Out:
# s=5
# s=15

# %%
dir(summa)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add']

# %%
summa.add(7,8)
# Out:
# 15

# %%
# %time summa.add(7,8)
# Out:
# Wall time: 0 ns
# 15

# %%
# %timeit summa.add(7,8)
# Out:
# 2.88 µs ± 464 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import skgeom as sg
a = sg.Point2(5, 3)
b = sg.Point2(10, 8)
print(a, b)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8556/454234045.py in <module>
# ----> 1 import skgeom as sg
#       2 a = sg.Point2(5, 3)
#       3 b = sg.Point2(10, 8)
#       4 print(a, b)
#
# ModuleNotFoundError: No module named 'skgeom'
